# %% [markdown]
# # Gráficos básicos
#
# Información importante:
# * Documentación oficial de Altair: [altair-viz.github.io](https://altair-viz.github.io/index.html)
# * Repositorio en GitHub: [tacosdedatos/codigofacilito-dataviz-efectiva](https://github.com/tacosdedatos/codigofacilito-dataviz-efectiva)
#
# * La manera de codificar (encoding) datos en Altair
# * Objetos en Altair
#   - Ejes o _axes_
#   - Escalas o _scales_
#   - Marcas gráficas o _marks_
# * Configuraciones
#   - de elementos
#   - de gráficos

# %%
# %pip install altair vega_datasets

import altair as alt
import pandas as pd 
from vega_datasets import data as vega_data
data = vega_data.gapminder()
# Out:
# Requirement already satisfied: altair in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (5.5.0)
# Requirement already satisfied: vega_datasets in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (0.9.0)
# Requirement already satisfied: jinja2 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from altair) (1.40.0)
# Requirement already satisfied: packaging in c:\users\ramiro\appdata\roaming\python\python313\site-packages (from altair) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from altair) (4.13.2)
# Requirement already satisfied: pandas in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from vega_datasets) (2.2.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair) (0.25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair) (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from pandas->vega_datasets) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramiro\appdata\roaming\python\python313\site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from pandas->vega_datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramiro\appdata\local\programs\python\python313\lib\site-packages (from pandas->vega_datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ramiro\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data.head()
# Out:
#         year      country  cluster       pop  life_expect  fertility
# 0 1955-01-01  Afghanistan        0   8891209       30.332        7.7
# 1 1960-01-01  Afghanistan        0   9829450       31.997        7.7
# 2 1965-01-01  Afghanistan        0  10997885       34.020        7.7
# 3 1970-01-01  Afghanistan        0  12430623       36.088        7.7
# 4 1975-01-01  Afghanistan        0  14132019       38.438        7.7

# %%
data.dtypes
# Out:
# year           datetime64[ns]
# country                object
# cluster                 int64
# pop                     int64
# life_expect           float64
# fertility             float64
# dtype: object

# %%
pd.to_datetime(data['year'], format= '%Y')
# Out:
# 0     1955-01-01
# 1     1960-01-01
# 2     1965-01-01
# 3     1970-01-01
# 4     1975-01-01
#          ...
# 688   1985-01-01
# 689   1990-01-01
# 690   1995-01-01
# 691   2000-01-01
# 692   2005-01-01
# Name: year, Length: 693, dtype: datetime64[ns]

# %%
data['year'] = pd.to_datetime(data['year'], format= '%Y')

# %%
## Filtrar datos

# %%
mascara_country = data['country'] == 'Mexico'
data_pais = data[mascara_country]

# %% [markdown]
# ## Barras

# %%
alt.Chart(data_pais).mark_bar().encode(
    x = alt.X('year:T', title='Year'),
    y = alt.Y('pop', title = 'Población', axis = alt.Axis(format='.3s')),
    color = alt.Color('country'),
)
# Out:
# alt.Chart(...)

# %%
def pais_chart(pais: str = 'Mexico'):
    mascara_country = data['country'] == pais
    data_pais = data[mascara_country]
    grafico = alt.Chart(data_pais).mark_bar().encode(
        x = alt.X('year:T', title='Year'),
        y = alt.Y('pop', title = 'Población', axis = alt.Axis(format='.3s')),
        color = alt.Color('country'),
    )
    return grafico

# %%
pais_chart()
# Out:
# alt.Chart(...)

# %%
for pais in data['country'].unique():
    display(pais_chart(pais))
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %% [markdown]
# ## Barras+
